# %% [markdown]
# Ноутбук для нарезки даты на чанки и хранения в БД

# %% [markdown]
# ### Импорты

# %% [markdown]
# ### Загрузка даты

# %% [markdown]
# ### Нарезка чанков

# %% [markdown]
# ### Сохранение чанков

# %% [markdown]
# ### Проверка
